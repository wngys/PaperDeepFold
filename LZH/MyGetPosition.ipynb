# %%
import numpy
import scipy
import scipy.spatial

# %%
pdb_path = "./fsdownload/d1bd7a_.ent"

# %%
CA_positions = []

# %%
with open(pdb_path, 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        if line[:4] != "ATOM":
            continue
        line_split = line.split()
        if line_split[2] == "CA":
            position = [float(line_split[6]), float(line_split[7]), float(line_split[8])]
            CA_positions.append(position)

# %%
CA_positions
# Out:
# [[18.366, -4.036, 1.195],
#  [22.139, -4.096, 1.654],
#  [23.528, -7.514, 2.499],
#  [26.937, -9.191, 2.512],
#  [27.767, -12.726, 3.535],
#  [31.185, -13.829, 4.713],
#  [32.291, -17.467, 4.633],
#  [34.955, -19.43, 6.52],
#  [36.4, -21.619, 3.744],
#  [36.852, -20.842, 0.024],
#  [34.04, -21.273, -2.528],
#  [31.282, -20.294, -0.078],
#  [31.555, -23.234, 2.314],
#  [31.886, -23.488, 6.107],
#  [30.406, -21.371, 8.917],
#  [28.975, -17.996, 7.849],
#  [27.823, -14.595, 8.936],
#  [25.218, -12.55, 7.093],
#  [25.301, -8.771, 7.681],
#  [22.257, -6.688, 6.778],
#  [22.803, -2.898, 6.465],
#  [24.746, -2.501, 9.759],
#  [28.483, -1.849, 10.281],
#  [30.586, -4.352, 12.216],
#  [33.681, -3.013, 14.075],
#  [34.333, -6.381, 15.699],
#  [33.636, -9.829, 14.252],
#  [34.448, -11.404, 17.594],
#  [31.843, -9.269, 19.336],
#  [29.366, -10.549, 16.767],
#  [30.264, -14.18, 17.437],
#  [32.493, -14.784, 14.418],
#  [35.913, -15.935, 15.668],
#  [37.065, -17.568, 12.384],
#  [39.041, -16.596, 9.285],
#  [37.346, -15.353, 6.082],
#  [38.21, -16.925, 2.717],
#  [35.203, -16.18, 0.455],
#  [32.719, -13.279, 0.269],
#  [29.343, -12.819, -1.458],
#  [28.126, -9.222, -1.856],
#  [24.451, -9.155, -2.821],
#  [24.021, -5.391, -2.643],
#  [25.914, -2.23, -1.809],
#  [29.608, -1.38, -1.581],
#  [31.602, -2.347, 1.489],
#  [35.142, -2.004, 2.742],
#  [36.559, -4.88, 4.788],
#  [39.577, -4.459, 7.068],
#  [42.331, -6.74, 8.327],
#  [42.045, -5.818, 12.043],
#  [39.112, -4.753, 14.307],
#  [37.98, -1.128, 14.541],
#  [38.709, -0.63, 10.829],
#  [42.537, -0.962, 10.97],
#  [45.127, -2.634, 8.781],
#  [44.844, -3.504, 5.102],
#  [41.661, -2.235, 3.369],
#  [39.743, -4.395, 0.89],
#  [37.093, -2.93, -1.385],
#  [34.059, -5.18, -1.845],
#  [31.622, -4.236, -4.598],
#  [28.615, -6.311, -5.68],
#  [29.652, -9.81, -6.775],
#  [31.098, -13.134, -5.673],
#  [34.666, -13.637, -4.427],
#  [35.529, -17.37, -4.37],
#  [38.959, -17.039, -2.818],
#  [40.436, -14.252, -0.7],
#  [42.995, -13.489, -3.378],
#  [39.948, -12.227, -5.324],
#  [39.516, -9.311, -2.914],
#  [43.239, -8.549, -2.589],
#  [43.846, -10.295, 0.738],
#  [47.333, -11.832, 1.234],
#  [45.929, -13.847, 4.124],
#  [42.276, -14.679, 4.948],
#  [42.213, -12.258, 7.878],
#  [39.277, -9.822, 8.0],
#  [38.068, -8.592, 11.412],
#  [35.743, -5.645, 10.588],
#  [33.55, -4.447, 7.731],
#  [31.673, -1.214, 6.896],
#  [29.327, -0.025, 4.16],
#  [29.811, 2.988, 1.921],
#  [26.38, 4.611, 1.862],
#  [27.083, 8.118, 0.571],
#  [28.254, 8.565, -2.994],
#  [28.445, 11.893, -4.828],
#  [27.415, 12.609, -8.41],
#  [30.305, 13.677, -10.611],
#  [33.517, 12.235, -9.12],
#  [36.505, 14.577, -8.973],
#  [39.828, 14.21, -7.197],
#  [42.802, 16.508, -7.224],
#  [46.223, 15.226, -6.339],
#  [49.119, 17.554, -5.512],
#  [52.83, 16.848, -5.769],
#  [53.806, 18.003, -2.273],
#  [52.322, 18.221, 1.244],
#  [49.517, 20.464, 2.477],
#  [48.13, 20.9, -1.035],
#  [51.1, 22.648, -2.618],
#  [52.937, 22.131, -5.899],
#  [51.67, 21.074, -9.317],
#  [48.103, 19.826, -9.297],
#  [46.577, 16.965, -11.347],
#  [42.759, 16.703, -11.528],
#  [40.928, 13.493, -12.486],
#  [37.26, 12.563, -12.962],
#  [37.654, 9.023, -14.286],
#  [39.938, 5.96, -13.942],
#  [43.679, 6.374, -14.375],
#  [45.77, 3.175, -14.59],
#  [49.043, 5.109, -14.32],
#  [49.627, 8.444, -12.571],
#  [52.943, 9.067, -14.352],
#  [50.901, 9.813, -17.473],
#  [49.62, 13.014, -15.888],
#  [53.212, 14.168, -15.45],
#  [52.793, 13.426, -11.722],
#  [56.09, 12.501, -10.025],
#  [55.163, 11.912, -6.371],
#  [51.83, 12.037, -4.491],
#  [52.117, 14.482, -1.605],
#  [48.508, 15.375, -0.718],
#  [45.023, 14.506, -2.059],
#  [41.798, 16.486, -2.213],
#  [38.565, 14.599, -2.839],
#  [35.795, 16.91, -4.05],
#  [33.431, 14.052, -4.929],
#  [33.707, 10.305, -4.641],
#  [34.489, 7.922, -3.11],
#  [37.604, 6.96, -5.067],
#  [39.799, 3.893, -4.682],
#  [43.567, 4.149, -5.009],
#  [46.112, 1.369, -5.56],
#  [49.788, 1.084, -4.687],
#  [50.656, -0.204, -8.185],
#  [49.777, 0.547, -11.822],
#  [46.774, -1.052, -13.566],
#  [44.763, -1.138, -10.308],
#  [46.667, -3.808, -8.364],
#  [48.435, -4.032, -5.005],
#  [47.571, -2.332, -1.714],
#  [44.173, -0.57, -1.679],
#  [43.392, 2.84, -0.136],
#  [39.776, 4.158, -0.037],
#  [39.381, 7.962, -0.357],
#  [36.255, 9.758, 0.783],
#  [35.193, 13.398, 0.399],
#  [37.668, 15.39, 2.447],
#  [41.311, 16.446, 2.751],
#  [44.383, 14.184, 2.852],
#  [47.426, 16.459, 3.723],
#  [50.198, 13.821, 4.013],
#  [50.849, 10.284, 2.786],
#  [50.147, 8.974, 6.285],
#  [46.513, 10.137, 5.936],
#  [45.953, 7.198, 3.57],
#  [48.294, 4.566, 4.997],
#  [46.59, 2.933, 8.069],
#  [49.443, 0.584, 7.579],
#  [52.134, 3.193, 6.856],
#  [53.924, 0.607, 4.704],
#  [54.082, 2.351, 1.296],
#  [54.069, 6.04, 0.335],
#  [53.464, 5.466, -3.4],
#  [50.11, 5.603, -5.186],
#  [50.092, 4.636, -8.872],
#  [46.456, 4.203, -9.997],
#  [42.936, 5.507, -9.159],
#  [39.304, 4.645, -9.953],
#  [35.938, 6.392, -9.195],
#  [32.645, 5.629, -7.436],
#  [32.652, 2.019, -6.486],
#  [18.366, -4.036, 1.195],
#  [22.139, -4.096, 1.654],
#  [23.528, -7.514, 2.499],
#  [26.937, -9.191, 2.512],
#  [27.767, -12.726, 3.535],
#  [31.185, -13.829, 4.713],
#  [32.291, -17.467, 4.633],
#  [34.955, -19.43, 6.52],
#  [36.4, -21.619, 3.744],
#  [36.852, -20.842, 0.024],
#  [34.04, -21.273, -2.528],
#  [31.282, -20.294, -0.078],
#  [31.555, -23.234, 2.314],
#  [31.886, -23.488, 6.107],
#  [30.406, -21.371, 8.917],
#  [28.975, -17.996, 7.849],
#  [27.823, -14.595, 8.936],
#  [25.218, -12.55, 7.093],
#  [25.301, -8.771, 7.681],
#  [22.257, -6.688, 6.778],
#  [22.803, -2.898, 6.465],
#  [24.746, -2.501, 9.759],
#  [28.483, -1.849, 10.281],
#  [30.586, -4.352, 12.216],
#  [33.681, -3.013, 14.075],
#  [34.333, -6.381, 15.699],
#  [33.636, -9.829, 14.252],
#  [34.448, -11.404, 17.594],
#  [31.843, -9.269, 19.336],
#  [29.366, -10.549, 16.767],
#  [30.264, -14.18, 17.437],
#  [32.493, -14.784, 14.418],
#  [35.913, -15.935, 15.668],
#  [37.065, -17.568, 12.384],
#  [39.041, -16.596, 9.285],
#  [37.346, -15.353, 6.082],
#  [38.21, -16.925, 2.717],
#  [35.203, -16.18, 0.455],
#  [32.719, -13.279, 0.269],
#  [29.343, -12.819, -1.458],
#  [28.126, -9.222, -1.856],
#  [24.451, -9.155, -2.821],
#  [24.021, -5.391, -2.643],
#  [25.914, -2.23, -1.809],
#  [29.608, -1.38, -1.581],
#  [31.602, -2.347, 1.489],
#  [35.142, -2.004, 2.742],
#  [36.559, -4.88, 4.788],
#  [39.577, -4.459, 7.068],
#  [42.331, -6.74, 8.327],
#  [42.045, -5.818, 12.043],
#  [39.112, -4.753, 14.307],
#  [37.98, -1.128, 14.541],
#  [38.709, -0.63, 10.829],
#  [42.537, -0.962, 10.97],
#  [45.127, -2.634, 8.781],
#  [44.844, -3.504, 5.102],
#  [41.661, -2.235, 3.369],
#  [39.743, -4.395, 0.89],
#  [37.093, -2.93, -1.385],
#  [34.059, -5.18, -1.845],
#  [31.622, -4.236, -4.598],
#  [28.615, -6.311, -5.68],
#  [29.652, -9.81, -6.775],
#  [31.098, -13.134, -5.673],
#  [34.666, -13.637, -4.427],
#  [35.529, -17.37, -4.37],
#  [38.959, -17.039, -2.818],
#  [40.436, -14.252, -0.7],
#  [42.995, -13.489, -3.378],
#  [39.948, -12.227, -5.324],
#  [39.516, -9.311, -2.914],
#  [43.239, -8.549, -2.589],
#  [43.846, -10.295, 0.738],
#  [47.333, -11.832, 1.234],
#  [45.929, -13.847, 4.124],
#  [42.276, -14.679, 4.948],
#  [42.213, -12.258, 7.878],
#  [39.277, -9.822, 8.0],
#  [38.068, -8.592, 11.412],
#  [35.743, -5.645, 10.588],
#  [33.55, -4.447, 7.731],
#  [31.673, -1.214, 6.896],
#  [29.327, -0.025, 4.16],
#  [29.811, 2.988, 1.921],
#  [26.38, 4.611, 1.862],
#  [27.083, 8.118, 0.571],
#  [28.254, 8.565, -2.994],
#  [28.445, 11.893, -4.828],
#  [27.415, 12.609, -8.41],
#  [30.305, 13.677, -10.611],
#  [33.517, 12.235, -9.12],
#  [36.505, 14.577, -8.973],
#  [39.828, 14.21, -7.197],
#  [42.802, 16.508, -7.224],
#  [46.223, 15.226, -6.339],
#  [49.119, 17.554, -5.512],
#  [52.83, 16.848, -5.769],
#  [53.806, 18.003, -2.273],
#  [52.322, 18.221, 1.244],
#  [49.517, 20.464, 2.477],
#  [48.13, 20.9, -1.035],
#  [51.1, 22.648, -2.618],
#  [52.937, 22.131, -5.899],
#  [51.67, 21.074, -9.317],
#  [48.103, 19.826, -9.297],
#  [46.577, 16.965, -11.347],
#  [42.759, 16.703, -11.528],
#  [40.928, 13.493, -12.486],
#  [37.26, 12.563, -12.962],
#  [37.654, 9.023, -14.286],
#  [39.938, 5.96, -13.942],
#  [43.679, 6.374, -14.375],
#  [45.77, 3.175, -14.59],
#  [49.043, 5.109, -14.32],
#  [49.627, 8.444, -12.571],
#  [52.943, 9.067, -14.352],
#  [50.901, 9.813, -17.473],
#  [49.62, 13.014, -15.888],
#  [53.212, 14.168, -15.45],
#  [52.793, 13.426, -11.722],
#  [56.09, 12.501, -10.025],
#  [55.163, 11.912, -6.371],
#  [51.83, 12.037, -4.491],
#  [52.117, 14.482, -1.605],
#  [48.508, 15.375, -0.718],
#  [45.023, 14.506, -2.059],
#  [41.798, 16.486, -2.213],
#  [38.565, 14.599, -2.839],
#  [35.795, 16.91, -4.05],
#  [33.431, 14.052, -4.929],
#  [33.707, 10.305, -4.641],
#  [34.489, 7.922, -3.11],
#  [37.604, 6.96, -5.067],
#  [39.799, 3.893, -4.682],
#  [43.567, 4.149, -5.009],
#  [46.112, 1.369, -5.56],
#  [49.788, 1.084, -4.687],
#  [50.656, -0.204, -8.185],
#  [49.777, 0.547, -11.822],
#  [46.774, -1.052, -13.566],
#  [44.763, -1.138, -10.308],
#  [46.667, -3.808, -8.364],
#  [48.435, -4.032, -5.005],
#  [47.571, -2.332, -1.714],
#  [44.173, -0.57, -1.679],
#  [43.392, 2.84, -0.136],
#  [39.776, 4.158, -0.037],
#  [39.381, 7.962, -0.357],
#  [36.255, 9.758, 0.783],
#  [35.193, 13.398, 0.399],
#  [37.668, 15.39, 2.447],
#  [41.311, 16.446, 2.751],
#  [44.383, 14.184, 2.852],
#  [47.426, 16.459, 3.723],
#  [50.198, 13.821, 4.013],
#  [50.849, 10.284, 2.786],
#  [50.147, 8.974, 6.285],
#  [46.513, 10.137, 5.936],
#  [45.953, 7.198, 3.57],
#  [48.294, 4.566, 4.997],
#  [46.59, 2.933, 8.069],
#  [49.443, 0.584, 7.579],
#  [52.134, 3.193, 6.856],
#  [53.924, 0.607, 4.704],
#  [54.082, 2.351, 1.296],
#  [54.069, 6.04, 0.335],
#  [53.464, 5.466, -3.4],
#  [50.11, 5.603, -5.186],
#  [50.092, 4.636, -8.872],
#  [46.456, 4.203, -9.997],
#  [42.936, 5.507, -9.159],
#  [39.304, 4.645, -9.953],
#  [35.938, 6.392, -9.195],
#  [32.645, 5.629, -7.436],
#  [32.652, 2.019, -6.486]]

# %%
pdb_dist_mat = scipy.spatial.distance.squareform(scipy.spatial.distance.pdist(CA_positions, 'euclidean'))

# %%
pdb_dist_mat
# Out:
# array([[ 0.        ,  3.80129057,  6.35949243, ..., 22.92314263,
#         19.28201823, 17.3133065 ],
#        [ 3.80129057,  0.        ,  3.78497952, ..., 20.44777117,
#         16.95817682, 14.63475295],
#        [ 6.35949243,  3.78497952,  0.        , ..., 22.00305824,
#         18.82982642, 15.96420026],
#        ...,
#        [22.92314263, 20.44777117, 22.00305824, ...,  0.        ,
#          3.81052477,  6.10406471],
#        [19.28201823, 16.95817682, 18.82982642, ...,  3.81052477,
#          0.        ,  3.73291428],
#        [17.3133065 , 14.63475295, 15.96420026, ...,  6.10406471,
#          3.73291428,  0.        ]])

# %%
numpy.isinf(pdb_dist_mat)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
numpy.sum(numpy.isinf(pdb_dist_mat))
# Out:
# 0

# %%
def get_distance_matrix_without_inf(pdb_path):
    CA_positions = []
    with open(pdb_path, 'r') as f:
        while True:
            line = f.readline()
            if not line:
                break
            if line[:4] != "ATOM":
                continue
            line_split = line.split()
            if line_split[2] == "CA":
                position = [float(line_split[6]), float(line_split[7]), float(line_split[8])]
                CA_positions.append(position)
    pdb_dist_mat = scipy.spatial.distance.squareform(scipy.spatial.distance.pdist(CA_positions, 'euclidean'))
    return pdb_dist_mat

# %%
print(get_distance_matrix_without_inf(pdb_path))
# Out:
# [[ 0.          3.80129057  6.35949243 ... 22.92314263 19.28201823
#   17.3133065 ]
#  [ 3.80129057  0.          3.78497952 ... 20.44777117 16.95817682
#   14.63475295]
#  [ 6.35949243  3.78497952  0.         ... 22.00305824 18.82982642
#   15.96420026]
#  ...
#  [22.92314263 20.44777117 22.00305824 ...  0.          3.81052477
#    6.10406471]
#  [19.28201823 16.95817682 18.82982642 ...  3.81052477  0.
#    3.73291428]
#  [17.3133065  14.63475295 15.96420026 ...  6.10406471  3.73291428
#    0.        ]]
